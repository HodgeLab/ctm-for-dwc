# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
station_data = pd.read_csv("/Users/robstallman/Downloads/Station_Data_Extract_Pipe_Delimited_CleanData_2021.txt", delimiter="|")
el_paso_stations = ["00A123", "00S162", "00A189", "2402", "000S70"]
station_data.loc[station_data['Station_Id'].isin(el_paso_stations)]
# Out:
# /var/folders/7m/3r23lm6s517bl9502bgqp64w0000gn/T/ipykernel_82931/3742981299.py:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   station_data = pd.read_csv("/Users/robstallman/Downloads/Station_Data_Extract_Pipe_Delimited_CleanData_2021.txt", delimiter="|")
#       Record_Type  State_Code Station_Id  Travel_Dir  Travel_Lane  \
# 24556           S          48     00A123           3            0
# 25540           S          48     00A123           7            0
# 25562           S          48     00A189           5            0
# 25629           S          48     00A189           1            0
#
#        Year_Record F_System  Num_Lanes Sample_Type_Volume  Num_Lanes_Volume  \
# 24556           21       1U          2                  T                 2
# 25540           21       1U          2                  T                 2
# 25562           21       3R          4                  T                 4
# ...

# %%
counts = pd.read_csv('/Users/robstallman/Downloads/jan_2021_ccs_data/TX_JAN_2021 (TMAS).VOL', delimiter='|')
counts.loc[counts['station_id'].isin(el_paso_stations)]
# Out:
#        record_type  state_code f_system station_id  travel_dir  travel_lane  \
# 12772            3          48       1U     00A123           3            0
# 12773            3          48       1U     00A123           3            0
# 12774            3          48       1U     00A123           3            0
# 12775            3          48       1U     00A123           3            0
# 12776            3          48       1U     00A123           3            0
# ...            ...         ...      ...        ...         ...          ...
# 13037            3          48       3R     00A189           5            0
# 13038            3          48       3R     00A189           5            0
# 13039            3          48       3R     00A189           5            0
# 13040            3          48       3R     00A189           5            0
# 13041            3          48       3R     00A189           5            0
#
# ...
